# %% [markdown]
# The focus of this challenge is:
# * Choose a more descriptive title for the bar chart
# * Redo the class analysis with data from a more recent month/year

# %% [markdown]
# # **Notebook for exploring data from the Brazilian Health Ministry repository**

# %% [markdown]
# [Link for data extraction](http://tabnet.datasus.gov.br/cgi/tabcgi.exe?sih/cnv/qiSP.def)
#
# **Access date and time:** 20th may, 2021 at 22h20
#
# **Information to access data:**
# * **Localização:** Informações de Saúde(TABNET)/Assistência à Saúde/Dados Consolidados AIH (RD), por local de internação, a partir de 2008/Brasil por município de São Paulo
# * **Linha:** Município
# * **Coluna:** Ano/mes processamento
# * **Conteúdo:** Valor Total
# * **Período:** de Jan-2008 à Mar-2021

# %% [markdown]
# ## **1. Importing software libraries**

# %%
import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

# %% [markdown]
# ## **2. Importing and reading data**

# %%
url_dados = 'https://github.com/SaraZachi/BootCamp-2021/blob/main/Aula%201/Data/A001458189_28_143_208.csv?raw=true'
dados = pd.read_csv(url_dados, encoding='ISO-8859-1', engine='python',
                    skiprows=3, skipfooter=12, sep=';', 
                    thousands='.', decimal=',')
dados
# Out:
#                        Município     2008/Jan  ...      2021/Mar         Total
# 0              350010 Adamantina    192360.05  ...     843298.96  6.598802e+07
# 1                   350030 Aguaí     58020.37  ...             -  4.672765e+06
# 2        350050 Águas de Lindóia     36102.19  ...      30613.53  8.013242e+06
# 3                  350070 Agudos     41090.60  ...      53310.41  9.783863e+06
# 4             350100 Altinópolis     22628.13  ...      33494.84  4.781172e+06
# ..                           ...          ...  ...           ...           ...
# 355             355680 Viradouro     27566.36  ...      13067.88  3.327839e+06
# 356  355690 Vista Alegre do Alto      1638.60  ...             -  8.756045e+04
# 357            355700 Votorantim    130982.55  ...     596052.93  3.085865e+07
# 358           355710 Votuporanga    200699.61  ...    1559836.72  1.539397e+08
# 359                        Total  91678473.48  ...  392946147.42  4.139660e+10
#
# ...

# %% [markdown]
# 2.1. Analysing dataframe (DF)
#
# *   The df documented 359 municipalities + Lables, giving us 360 rows
# *   From Jan/2008 to Mar/2021, we have 13 years * 12 months (hole years) + 3 months (from Jan-Mar/2021), which gives us 159 columns + 2 for lable amd city name, giving us 161 columns
#
# Therfore, our dataframe has 360 rows × 161 columns

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Columns: 161 entries, Município to Total
# dtypes: float64(1), object(160)
# memory usage: 452.9+ KB

# %% [markdown]
# ## **3. Formatting data**

# %% [markdown]
# 3.1. As default or data was presented in scientific notation. In order to change that, we use the following codes to present them with two numbers decimals.

# %%
pd.options.display.float_format = '{:.2f}'.format
dados['2008/Abr'].mean
# Out:
# <bound method Series.mean of 0         304813.18
# 1          57386.91
# 2          42259.47
# 3          79860.83
# 4          23629.02
#            ...
# 355        31829.34
# 356         2583.86
# 357       165420.20
# 358       413376.22
# 359    161227125.43
# Name: 2008/Abr, Length: 360, dtype: object>

# %% [markdown]
# 3.2. In order to plot a bar chart with the amount of money spent by São Paulo with the Brazilian public health plan during December 2020, the blank spots in the data frame '2020/Dez' column had to be substituted with a number (0). These 'blank spots' are identified with '-'. Therefore, the following code was applied.

# %%
dados['2020/Dez'] = dados['2020/Dez'].replace('-', 0.0)
dados['2020/Dez'] = dados['2020/Dez'].astype(float)

# %%
dados['2020/Dez']
# Out:
# 0        464135.09
# 1             0.00
# 2         51543.40
# 3         30959.27
# 4         21347.98
#           ...
# 355       25942.46
# 356           0.00
# 357      432882.75
# 358     1338367.09
# 359   330489045.98
# Name: 2020/Dez, Length: 360, dtype: float64

# %% [markdown]
# 3.3. The main data frame has way too many cities to fit in a single bar chart, therefore, only the top 10 on the list will be used for this project.

# %%
cod_municipios = dados['Município'].head(10)
cod_municipios
# Out:
# 0             350010 Adamantina
# 1                  350030 Aguaí
# 2       350050 Águas de Lindóia
# 3                 350070 Agudos
# 4            350100 Altinópolis
# 5            350110 Alto Alegre
# 6        350130 Álvares Machado
# 7              350160 Americana
# 8    350170 Américo Brasiliense
# 9                 350190 Amparo
# Name: Município, dtype: object

# %%
data = dados.query('Município in @cod_municipios')
data
# Out:
#                     Município   2008/Jan  ...    2021/Mar        Total
# 0           350010 Adamantina  192360.05  ...   843298.96  65988020.00
# 1                350030 Aguaí   58020.37  ...           -   4672764.57
# 2     350050 Águas de Lindóia   36102.19  ...    30613.53   8013242.34
# 3               350070 Agudos   41090.60  ...    53310.41   9783863.36
# 4          350100 Altinópolis   22628.13  ...    33494.84   4781172.12
# 5          350110 Alto Alegre          -  ...    14866.93    500620.49
# 6      350130 Álvares Machado   23728.79  ...    37242.66   3451455.69
# 7            350160 Americana  305067.02  ...  1229942.10 106677845.34
# 8  350170 Américo Brasiliense  109992.37  ...   181380.53  67690877.56
# 9               350190 Amparo  380701.11  ...  1342732.95  86893388.59
#
# [10 rows x 161 columns]

# %%
xticks = ['350010 Adamantina', '350030 Aguaí', '350050 Águas de Lindóia0', '350070 Agudos', '350100 Altinópolis', '350110 Alto Alegre', 
          '350130 Álvares Machado', ' 350160 Americana', '350170 Américo Brasiliense', '350190 Amparo']
xticks
# Out:
# ['350010 Adamantina',
#  '350030 Aguaí',
#  '350050 Águas de Lindóia0',
#  '350070 Agudos',
#  '350100 Altinópolis',
#  '350110 Alto Alegre',
#  '350130 Álvares Machado',
#  ' 350160 Americana',
#  '350170 Américo Brasiliense',
#  '350190 Amparo']

# %% [markdown]
# ## **04. Plotting a bar chart**

# %%
sns.set()
ax = data.sort_values(by = '2020/Dez', ascending=False).plot(x='Município', y='2020/Dez', kind='bar', 
                figsize=(10,6),
                color='#fdbf11')

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title('Amount spent on public medical care in 10 cities of São Paulo on December 2020', fontsize=16, 
          fontweight='bold', 
          color='#000000')

plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

ax.set_xlabel('Municipalitie', fontsize=14, fontweight='bold', color='#000000')
ax.set_ylabel('Amount spent (R$)', fontsize=14, fontweight='bold', color='#000000')

plt.show()
