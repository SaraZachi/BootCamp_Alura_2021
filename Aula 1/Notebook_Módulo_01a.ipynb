# %% [markdown]
# **Caderno de exploração dos dados do datasus**
#
# Indica o valor total gasto por Ano/mês, a partir de 2008, em ambiente hospitalar, no SUS, segundo Unidade da Federação

# %% [markdown]
# # **01. Aquisição de leitura de dados reais**

# %%
import pandas as pd
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

import numpy as np

import seaborn as sns
sns.set()

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

# %%
link_dados = 'https://github.com/SaraZachi/BootCamp-2021/blob/main/Aula%201/Data/A151346189_28_143_208.csv?raw=true'
dados = pd.read_csv(link_dados,encoding = 'ISO-8859-1',
                    skiprows = 3, sep=';',skipfooter=12,
                    thousands = ".", decimal =',')
dados
## Erros ocorridos e soluções
# [01] Erro devido ao acento no a (ã) da linguagem portuguesa
# para resolver foi necessário idicar no código uma linguagem padrão a ser utilizada: encoding = 'ISO-8859-1'
# [02] Erro de formatação do arquivo. Nem todas as linhas possuem o separador ';'
# para resolver descartar/ignorar as linhas sem o separador (;) e indicar qual é o separador: skiprows = 3, sep=';',skipfooter=12
# [03] Indicar os separadores decimais e milhar para não dar erro na formatação dos dados: thousands = ".", decimal =',')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
#       Unidade da Federação    2008/Jan  ...      2020/Ago          Total
# 0              11 Rondônia  1388528.39  ...   10285455.78   929129659.72
# 1                  12 Acre   902416.00  ...             -   420668039.63
# 2              13 Amazonas  4735529.42  ...   14726443.67  1771654871.23
# 3               14 Roraima   657889.53  ...    2826486.18   305010883.18
# 4                  15 Pará 18864744.11  ...   39911193.02  4437115730.71
# 5                 16 Amapá  1120973.34  ...    2942273.94   291637984.75
# 6             17 Tocantins  3441592.69  ...    8240261.38   999998621.85
# 7              21 Maranhão 10723506.39  ...   28587541.78  3632860959.84
# ...

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %% [markdown]
# a média dos dados foi dada em notação científica. Para alterar este formato realizamos a seguinte sequência de códigos

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 154 entries, Unidade da Federação to Total
# dtypes: float64(151), object(3)
# memory usage: 32.6+ KB

# %%
pd.options.display.float_format = '{:.2f}'.format
# {:.2f} = função que utiliza 2 casas decimais

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %%
dados['2008/Jan']
# Out:
# 0     1388528.39
# 1      902416.00
# 2     4735529.42
# 3      657889.53
# 4    18864744.11
# 5     1120973.34
# 6     3441592.69
# 7    10723506.39
# 8     7985142.43
# 9    15539821.90
# 10    5947814.08
# 11   10723002.45
# 12   14393949.89
# 13    6243726.32
# 14    2780750.11
# 15   21211522.47
# 16   45671659.76
# 17    5456723.98
# 18   23025258.52
# 19   91678473.48
# 20   38266347.46
# 21   16504913.45
# 22   30931325.46
# 23    5377392.11
# 24    4795299.01
# 25   15310637.29
# 26    4745919.19
# Name: 2008/Jan, dtype: float64

# %%
dados['2008/Ago'].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago')

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(9,6))

# %% [markdown]
# # **Challenges**

# %% [markdown]
# **Challenge 1.1. Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.**

# %%
ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(10,6))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
# https://matplotlib.org/stable/gallery/ticks_and_spines/tick-formatters.html

plt.title('Valor gasto por Unidade de Federação em agosto de 2008', fontsize=16, fontweight='bold')
ax.set_xlabel('Unidade da Federação', fontsize=12, fontweight='bold')
ax.set_ylabel('Valor gasto (R$)', fontsize=12, fontweight='bold')

plt.show()

# %% [markdown]
# **Challenge 1.2. Faça a mesma análise realizada em aula, porém para o mês mais recente.**

# %%
pd.options.display.float_format = '{:.2f}'.format
dados['2020/Ago'].mean
# Out:
# <bound method Series.mean of 0      10285455.78
# 1                -
# 2      14726443.67
# 3       2826486.18
# 4      39911193.02
# 5       2942273.94
# 6       8240261.38
# 7      28587541.78
# 8      23210624.20
# 9      59808605.59
# 10     24929930.72
# 11     22130016.81
# 12     75704177.72
# 13     19754741.78
# 14     11014180.89
# 15     80793117.08
# 16    168024412.95
# 17     32188873.88
# 18     95274486.35
# 19    346512263.17
# 20    129375911.54
# 21     63972379.36
# 22    101374341.51
# 23     19241624.02
# 24     17790649.87
# 25     43984702.05
# 26     26526196.39
# Name: 2020/Ago, dtype: object>

# %%
ax = dados['2020/Ago'].plot(kind='bar', figsize=(10,6))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title('Valor gasto por Unidade de Federação em agosto de 2008', fontsize=16, fontweight='bold')
ax.set_xlabel('Unidade da Federação', fontsize=12, fontweight='bold')
ax.set_ylabel('Valor gasto (R$)', fontsize=12, fontweight='bold')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-46cdbddd62fd> in <module>()
# ----> 1 ax = dados['2020/Ago'].plot(kind='bar', figsize=(10,6))
#       2
#       3 ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
#       4
#       5 plt.title('Valor gasto por Unidade de Federação em agosto de 2008', fontsize=16, fontweight='bold')
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...
