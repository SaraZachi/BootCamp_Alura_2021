# %% [markdown]
# # **2. Primeiras visualizações de dados**

# %% [markdown]
# ## **2.1. Importing libraries & data**

# %%
import pandas as pd

import numpy as np

import seaborn as sns
sns.set()

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

# %%
link_dados = 'https://github.com/SaraZachi/BootCamp-2021/blob/main/Aula%202/Data/A160324189_28_143_208.csv?raw=true'
dados = pd.read_csv(link_dados,encoding = 'ISO-8859-1',
                    skiprows = 3, sep=';',skipfooter=12,
                    thousands = ".", decimal =',')
dados
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
#       Unidade da Federação  1992/Mar  ...      2020/Ago         Total
# 0              11 Rondônia         -  ...    3556381.57  9.291297e+08
# 1                  12 Acre         -  ...             -  4.206680e+08
# 2              13 Amazonas         -  ...    4726485.73  1.771655e+09
# 3               14 Roraima         -  ...    1524478.04  3.050109e+08
# 4                  15 Pará         -  ...   11559714.54  4.437116e+09
# 5                 16 Amapá         -  ...     834187.31  2.916380e+08
# 6             17 Tocantins         -  ...    2453362.74  9.999986e+08
# 7              21 Maranhão         -  ...   10916718.78  3.632861e+09
# 8                 22 Piauí         -  ...    7926321.69  2.130616e+09
# 9                 23 Ceará         -  ...   14559529.59  6.197357e+09
# 10  24 Rio Grande do Norte         -  ...    8080160.97  2.477372e+09
# 11              25 Paraíba         -  ...    8585226.08  2.470550e+09
# 12           26 Pernambuco         -  ...   33544876.14  8.046954e+09
# 13              27 Alagoas         -  ...    6487947.82  2.104405e+09
# 14              28 Sergipe         -  ...    1742127.72  1.130337e+09
# 15                29 Bahia         -  ...   26023558.53  9.193803e+09
# 16         31 Minas Gerais         -  ...   57473699.06  1.916011e+10
# 17       32 Espírito Santo         -  ...   10824255.26  3.139189e+09
# 18       33 Rio de Janeiro         -  ...   36264322.65  9.696363e+09
# 19            35 São Paulo  40243.16  ...  140414944.95  3.892935e+10
# 20               41 Paraná         -  ...   41542401.16  1.378696e+10
# 21       42 Santa Catarina         -  ...   16991236.43  7.324100e+09
# 22    43 Rio Grande do Sul         -  ...   28349257.38  1.195865e+10
# 23   50 Mato Grosso do Sul         -  ...    4059220.22  2.172158e+09
# 24          51 Mato Grosso         -  ...    6174224.99  2.036924e+09
# 25                52 Goiás         -  ...   20242641.73  4.657349e+09
# 26     53 Distrito Federal         -  ...   12044848.02  2.429933e+09
#
# [27 rows x 280 columns]

# %% [markdown]
# ## **2.2. Making diferent slices of the dataframe**

# %% [markdown]
# ### **2.2.1. Slice of two columns**

# %%
dados[['2008/Ago', '2008/Set']].head()
# Out:
#       2008/Ago     2008/Set
# 0   2938286.29   2843930.91
# 1   1886871.84   2084884.80
# 2   8331763.97   8148089.92
# 3   1045291.11   1003740.89
# 4  23259148.28  23667690.01

# %% [markdown]
# ### **2.2.2. Slice of non-null columns**

# %%
# Selecting / separating only columns with non-null values

## For this, it was necessary to: 
## 1) identify the columns with non-null values;
## 2) define the index of non-null columns to perform the slice later;
## 3) insert/add the 'Unidade da Federação' column in the position zero of the index.

## For the 3rd step it was necessary to add '.tolist ()' to the first line of the code 
## in order to transform 'colunas_usaveis' into a python list, which is mutable, as opposed
## to .index, which is immutable.

colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, 'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  'Total']

# %%
# Slice of months/year with non-zero values
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação   2007/Ago  ...     2020/Jul         Total
# 0          11 Rondônia    4209.37  ...   7407388.24  9.291297e+08
# 1              12 Acre   10470.07  ...   1163813.08  4.206680e+08
# 2          13 Amazonas   35752.72  ...  13358514.02  1.771655e+09
# 3           14 Roraima    4785.91  ...   2739498.41  3.050109e+08
# 4              15 Pará  181159.29  ...  27618727.51  4.437116e+09
#
# [5 rows x 158 columns]

# %%
# Returning 'Unidade da Federação' as the index for our new slice
usaveis = usaveis.set_index('Unidade da Federação')
usaveis
# Out:
#                           2007/Ago    2007/Set  ...      2020/Jul         Total
# Unidade da Federação                            ...
# 11 Rondônia                4209.37    16397.03  ...  7.407388e+06  9.291297e+08
# 12 Acre                   10470.07    14001.71  ...  1.163813e+06  4.206680e+08
# 13 Amazonas               35752.72    45570.64  ...  1.335851e+07  1.771655e+09
# 14 Roraima                 4785.91    11858.63  ...  2.739498e+06  3.050109e+08
# 15 Pará                  181159.29   433414.74  ...  2.761873e+07  4.437116e+09
# 16 Amapá                  33672.74   104822.98  ...  2.155083e+06  2.916380e+08
# 17 Tocantins               4113.76    76633.06  ...  4.489666e+06  9.999986e+08
# 21 Maranhão              385330.18  1018352.93  ...  2.437421e+07  3.632861e+09
# 22 Piauí                 220788.25   353468.67  ...  1.801921e+07  2.130616e+09
# 23 Ceará                 357904.65   572356.18  ...  3.080922e+07  6.197357e+09
# 24 Rio Grande do Norte   134605.36   272088.08  ...  1.959306e+07  2.477372e+09
# 25 Paraíba                97352.78   368130.43  ...  1.549147e+07  2.470550e+09
# 26 Pernambuco            400640.85  1088340.42  ...  6.232544e+07  8.046954e+09
# 27 Alagoas               104243.75   174024.90  ...  1.308785e+07  2.104405e+09
# 28 Sergipe                27453.63    78565.19  ...  3.312766e+06  1.130337e+09
# 29 Bahia                 135146.36   448349.75  ...  5.889810e+07  9.193803e+09
# 31 Minas Gerais          971394.37  2861781.50  ...  1.204672e+08  1.916011e+10
# 32 Espírito Santo         57408.11   284224.80  ...  2.746048e+07  3.139189e+09
# 33 Rio de Janeiro        469469.34   921646.57  ...  7.154023e+07  9.696363e+09
# 35 São Paulo            1665349.90  4434168.64  ...  2.827096e+08  3.892935e+10
# 41 Paraná                554800.22  1431708.01  ...  8.032085e+07  1.378696e+10
# 42 Santa Catarina        693955.05  1092964.12  ...  5.176453e+07  7.324100e+09
# 43 Rio Grande do Sul    1049252.33  3182913.14  ...  7.892970e+07  1.195865e+10
# 50 Mato Grosso do Sul    199556.12   573675.41  ...  1.250872e+07  2.172158e+09
# 51 Mato Grosso            63562.50   232444.62  ...  1.308315e+07  2.036924e+09
# 52 Goiás                 179395.82   418053.58  ...  3.349928e+07  4.657349e+09
# 53 Distrito Federal      191951.47   769966.25  ...  2.223354e+07  2.429933e+09
#
# [27 rows x 157 columns]

# %%
# Transposing (T) the Data Frame (DF)
usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia  ...  53 Distrito Federal
# 2020/Abr              7.423679e+06  ...         1.812390e+07
# 2020/Mai              8.581195e+06  ...         2.143743e+07
# 2020/Jun              9.193594e+06  ...         2.347977e+07
# 2020/Jul              7.407388e+06  ...         2.223354e+07
# Total                 9.291297e+08  ...         2.429933e+09
#
# [5 rows x 27 columns]

# %%
# Remooving/droping (drop) the line 'Total' from the DF
usaveis = usaveis.drop('Total', axis=1)
usaveis.head()
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                        ...
# 11 Rondônia             4209.37   16397.03  ...   9193593.76   7407388.24
# 12 Acre                10470.07   14001.71  ...   2199920.70   1163813.08
# 13 Amazonas            35752.72   45570.64  ...  17509334.66  13358514.02
# 14 Roraima              4785.91   11858.63  ...   3216466.51   2739498.41
# 15 Pará               181159.29  433414.74  ...  35396030.78  27618727.51
#
# [5 rows x 156 columns]

# %%
usaveis_plot = usaveis.columns[5:]
usaveis_plot
# Out:
# Index(['2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai', '2008/Jun',
#        '2008/Jul', '2008/Ago', '2008/Set', '2008/Out',
#        ...
#        '2019/Out', '2019/Nov', '2019/Dez', '2020/Jan', '2020/Fev', '2020/Mar',
#        '2020/Abr', '2020/Mai', '2020/Jun', '2020/Jul'],
#       dtype='object', length=151)

# %%
usaveis = usaveis[usaveis_plot]/1000000
usaveis
# Out:
#                            2008/Jan    2008/Fev  ...    2020/Jun    2020/Jul
# Unidade da Federação                             ...
# 11 Rondônia                1.829560    1.940793  ...    9.193594    7.407388
# 12 Acre                    1.731745    1.743979  ...    2.199921    1.163813
# 13 Amazonas               11.419210    7.934652  ...   17.509335   13.358514
# 14 Roraima                 0.808448    0.771688  ...    3.216467    2.739498
# 15 Pará                   21.762104   20.126081  ...   35.396031   27.618728
# 16 Amapá                   1.329877    1.275064  ...    2.699492    2.155083
# 17 Tocantins               5.136475    5.051932  ...    5.018138    4.489666
# 21 Maranhão               21.551600   13.452264  ...   31.128145   24.374205
# 22 Piauí                  11.375419    9.711680  ...   15.375524   18.019214
# 23 Ceará                  32.444329   27.643305  ...   42.146556   30.809221
# 24 Rio Grande do Norte    11.763899    9.110109  ...   20.219962   19.593057
# 25 Paraíba                16.599005   10.871590  ...   19.666097   15.491469
# 26 Pernambuco             51.219114   26.222079  ...   68.145111   62.325444
# 27 Alagoas                16.503978    8.112220  ...   14.278872   13.087850
# 28 Sergipe                 5.439986    4.636851  ...    6.705923    3.312766
# 29 Bahia                  73.336297   33.410124  ...   65.159301   58.898100
# 31 Minas Gerais          205.912744   70.301090  ...  135.977572  120.467187
# 32 Espírito Santo         16.212109   10.032886  ...   27.450865   27.460475
# 33 Rio de Janeiro        250.564960   44.122593  ...   77.604925   71.540227
# 35 São Paulo            1023.564534  172.834915  ...  299.060852  282.709570
# 41 Paraná                 58.081334   48.855046  ...   92.901461   80.320853
# 42 Santa Catarina         53.034385   24.409573  ...   56.503748   51.764535
# 43 Rio Grande do Sul      51.064610   45.897705  ...   89.019479   78.929704
# 50 Mato Grosso do Sul      8.301006    8.279289  ...   15.838659   12.508717
# 51 Mato Grosso             8.213439    7.929895  ...   14.585009   13.083152
# 52 Goiás                  74.063828   18.149374  ...   34.437633   33.499284
# 53 Distrito Federal       10.561085   10.215957  ...   23.479773   22.233542
#
# [27 rows x 151 columns]

# %% [markdown]
# # **Challenge: Plot a graph with only 5 states and properly position the legend**

# %%
ax = usaveis[:5].T.plot(figsize=(12,8), cmap=plt.get_cmap('plasma_r'))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))

plt.title('DATASUS: Monthly Hospital Expenses of 5 Brazilian FU ', fontsize=16, 
          fontweight='bold')

plt.xticks(fontsize=10)

plt.legend(bbox_to_anchor=(1.05, 1))

ax.set_xlabel('Months (from Jan/2008 to Jul/2020)', fontsize=14, fontname = "Arial", fontweight='bold', color='#000000')
ax.set_ylabel('Amount spent (1,000,000.00 R$)', fontsize=14, fontname = "Arial", fontweight='bold', color='#000000')

plt.show()

# %% [markdown]
# Legends ref.: https://matplotlib.org/1.3.1/users/legend_guide.html
